# %%
'''Q1. What is Flask Framework? What are the advantages of Flask Framework?'''

'''flask is REST architecture type of API which uses HTTP for the communication and
interaction btw web and application

ADVANTAGES-

1. it is used for web based communication.
2.it uses only HTTP .
3. it is very easy to use ,good scalability , flexibility .
4.it is stateless, i.e.., it doesn't save any type of data .'''

# %%
'''Q2. Create a simple Flask application to display ‘Hello World!!’. Attach the screenshot of the output in
Jupyter Notebook.'''

'''from flask import Flask

app= Flask(__name__)

@app.route("/sahi")
def disp():
    return "Hello World!!"



if __name__=='__main__':
    app.run(host="0.0.0.0")
    
    


'''
# Out:
# 'from flask import Flask\n\napp= Flask(__name__)\n\n@app.route("/sahi")\ndef disp():\n    return "Hello World!!"\n\n\n\nif __name__==\'__main__\':\n    app.run(host="0.0.0.0")\n    \n    \n\n\n'

# %% [markdown]
# ![hello.jpg](attachment:3629242d-f43c-4aaa-ab77-10578dfda939.jpg)

# %%
'''Q3. What is App routing in Flask? Why do we use app routes?'''

'''App routing refers to giving path to the web to show desired ouput.

we use app routes to decorate a function and give it a path to get the output on the web.'''
# Out:
# 'Q3. What is App routing in Flask? Why do we use app routes?'

# %%
'''Q4. Create a “/welcome” route to display the welcome message “Welcome to ABC Corporation” and a “/”
route to show the following details:
Company Name: ABC Corporation
Location: India
Contact Detail: 999-999-9999'''

'''from flask import Flask

app= Flask(__name__)

@app.route("/welcome")
def disp1():
    return "Welcome to ABC Corporation"

@app.route("/")
def disp2():

    info = {
        "Company Name": "ABC Corporation",
"Location": "India",
"Contact Detail": 999-999-9999
    }
    return info



if __name__=='__main__':
    app.run(host="0.0.0.0")


'''

# %% [markdown]
# ![welcome.PNG](attachment:5075224c-1c89-46dc-af14-833caa3b8501.PNG)

# %% [markdown]
# ![disp.PNG](attachment:bc0c0919-dac6-49b3-b1ba-3f465e225dd4.PNG)

# %%
'''Q5. What function is used in Flask for URL Building? Write a Python code to demonstrate the working of the
url_for() function.'''

# from flask import Flask, url_for

# app = Flask(__name__)


# @app.route('/')
# def home():
#     return "Welcome to the Home Page!"


# @app.route('/about')
# def about():
#     return "This is the About Page!"


# @app.route('/contact')
# def contact():
#     return "Contact us at contactno."



# if __name__ == '__main__':
#     with app.test_request_context():
        
#         home_url = url_for('home')
#         about_url = url_for('about')
#         contact_url = url_for('contact')
        

        
#         print(f"Home URL: {home_url}")
#         print(f"About URL: {about_url}")
#         print(f"Contact URL: {contact_url}")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[9], line 4
#       1 '''Q5. What function is used in Flask for URL Building? Write a Python code to demonstrate the working of the
#       2 url_for() function.'''
# ----> 4 from flask import Flask, url_for
#       6 app = Flask(__name__)
#       9 @app.route('/')
#      10 def home():
#
# ModuleNotFoundError: No module named 'flask'
