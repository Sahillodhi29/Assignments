# %%
'''Q1. Explain why we have to use the Exception class while creating a Custom Exception.'''

#  because catching classes that do not inherit from BaseException class is not allowed
# Out:
# 'Q1. Explain why we have to use the Exception class while creating a Custom Exception.'

# %%
'''Q2. Write a python program to print Python Exception Hierarchy.'''

def print_exception_hierarchy(exception_class, indent=0):
    print(" " * indent + exception_class.__name__)
    for subclass in exception_class.__subclasses__():
        print_exception_hierarchy(subclass, indent + 4)

if __name__ == "__main__":
    print("Python Exception Hierarchy:")
    print_exception_hierarchy(BaseException)
# Out:
# Python Exception Hierarchy:
# BaseException
#     Exception
#         TypeError
#             FloatOperation
#             MultipartConversionError
#         StopAsyncIteration
#         StopIteration
#         ImportError
#             ModuleNotFoundError
#             ZipImportError
#         OSError
#             ConnectionError
#                 BrokenPipeError
#                 ConnectionAbortedError
#                 ConnectionRefusedError
#                 ConnectionResetError
#                     RemoteDisconnected
#             BlockingIOError
#             ChildProcessError
#             FileExistsError
#             FileNotFoundError
#             IsADirectoryError
#             NotADirectoryError
#             InterruptedError
#                 InterruptedSystemCall
#             PermissionError
#             ProcessLookupError
#             TimeoutError
#             UnsupportedOperation
#             itimer_error
#             herror
#             gaierror
# ...

# %%
'''Q3. What errors are defined in the ArithmeticError class? Explain any two with an example.'''

try:
    1/0
except ArithmeticError as e:
    print(e)
# Out:
# division by zero

# %%
j = 5.0

try:
    for i in range(1, 1000):
        j = j**i
except ArithmeticError as e:
    print(e)
# Out:
# (34, 'Numerical result out of range')

# %%
'''Q4. Why LookupError class is used? Explain with an example KeyError and IndexError.'''

try:
    l=[12,3,5,67]
    print(l[7])
    
except LookupError as e:
    print(e)
# Out:
# list index out of range

# %%
try :
    d={
    "name":"sahil",
        "course":"data science"
    }
    
    print(d["pokemon"])
    
   
except LookupError as e:
    print(e)
# Out:
# 'pokemon'

# %%
d={
    "name":"sahil",
        "course":"data science"
    }
    
print(d["pokemon"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[7], line 6
#       1 d={
#       2     "name":"sahil",
#       3         "course":"data science"
#       4     }
# ----> 6 print(d["pokemon"])
#
# KeyError: 'pokemon'

# %%
'''Q5. Explain ImportError. What is ModuleNotFoundError? '''

import sahil 

print("this is my new programm")

# %%
""" when we try to import a module which doesn't exist ,then we get an importerror , now let us handle it 
by making an exception for it """

try :
    import sahil
    
except ModuleNotFoundError as e :
    print(e)
    
finally :
    print("this is my new program")

# %%
'''Q6. list down some best practices for exception handling in python

1. don't use generic exception keyword "Exception", instead of that use specific exception handling keywords like
   ZeroDivisionError, FileNotFoundError, etc .
   
2. don't write all eception keywords at once , try to handle a particular error with it's respective exception.

3. whenever you are using generic exception"Exception" , always use it in the last, otherwise if u write it in the 
   initial of exceptions , all the exceptions will be handled by it only , and the other specific exception won't get
   a chance to handle it .
